# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pokemon=pd.read_csv('C:\\Users\\AHTESHAM\\Downloads\\all_pokemon.csv')

# %%
pokemon
# Out:
#         #         Name      Type  Total   HP  Attack  Defense  Sp. Atk  \
# 0       1    Bulbasaur     Grass    318   45      49       49       65
# 1       1    Bulbasaur    Poison    318   45      49       49       65
# 2       2      Ivysaur     Grass    405   60      62       63       80
# 3       2      Ivysaur    Poison    405   60      62       63       80
# 4       3     Venusaur     Grass    525   80      82       83      100
# ...   ...          ...       ...    ...  ...     ...      ...      ...
# 1415  806  Blacephalon      Fire    570   53     127       53      151
# 1416  806  Blacephalon     Ghost    570   53     127       53      151
# 1417  807      Zeraora  Electric    600   88     112       75      102
# 1418  808       Meltan     Steel    300   46      65       65       55
# 1419  809     Melmetal     Steel    600  135     143      143       80
#
#       Sp. Def  Speed
# 0          65     45
# 1          65     45
# 2          80     60
# 3          80     60
# ...

# %% [markdown]
# # a) How many Pokémon of each type are there?

# %%
pokemon['Type'].value_counts()
# Out:
# Water       143
# Normal      117
# Flying      113
# Grass       109
# Psychic     103
# Bug          83
# Ground       75
# Fire         74
# Poison       71
# Rock         70
# Fighting     63
# Electric     62
# Steel        62
# Dragon       61
# Dark         60
# Ghost        57
# Fairy        53
# Ice          44
# Name: Type, dtype: int64

# %% [markdown]
# # b)Which Pokémon type is the most powerful           ##highest total

# %%
pokemon[pokemon['Total']==pokemon['Total'].max()]
# Out:
#        #                   Name      Type  Total   HP  Attack  Defense  \
# 275  150    MewtwoMega Mewtwo X   Psychic    780  106     190      100
# 276  150    MewtwoMega Mewtwo X  Fighting    780  106     190      100
# 277  150    MewtwoMega Mewtwo Y   Psychic    780  106     150       70
# 677  384  RayquazaMega Rayquaza    Dragon    780  105     180      100
# 678  384  RayquazaMega Rayquaza    Flying    780  105     180      100
#
#      Sp. Atk  Sp. Def  Speed
# 275      154      100    130
# 276      154      100    130
# 277      194      120    140
# 677      180      100    115
# 678      180      100    115

# %% [markdown]
# # Find average values, variance for each property and plot them

# %%
pokemon['Total'].mean()
# Out:
# 445.8021126760563

# %%
sns.distplot(pokemon['Total'],bins=30,kde=False)

# %%
pokemon['HP'].mean()
# Out:
# 70.17605633802818

# %%
sns.distplot(pokemon['HP'],bins=30,kde=False)

# %%
pokemon['Attack'].mean()
# Out:
# 81.56760563380281

# %%
sns.distplot(pokemon['Attack'],bins=30,kde=False)

# %%
pokemon['Defense'].mean()
# Out:
# 76.51901408450705

# %%
sns.distplot(pokemon['Defense'],bins=30,kde=False)

# %%
pokemon['Sp. Atk'].mean()
# Out:
# 74.73661971830985

# %%
sns.distplot(pokemon['Sp. Atk'],bins=30,kde=False)

# %%
pokemon['Sp. Def'].mean()
# Out:
# 73.49718309859155

# %%
sns.distplot(pokemon['Sp. Def'],bins=30,kde=False)

# %%
pokemon['Speed'].mean()
# Out:
# 69.3056338028169

# %%
sns.distplot(pokemon['Speed'],bins=30,kde=False)

# %%
pokemon['Total'].var()
# Out:
# 14526.89175029031

# %%
pokemon['HP'].var()
# Out:
# 656.1395249580639

# %%
pokemon['Attack'].var()
# Out:
# 1082.489436123437

# %%
pokemon['Defense'].var()
# Out:
# 1009.0109137559652

# %%
pokemon['Sp. Atk'].var()
# Out:
# 1124.6620829983428

# %%
pokemon['Sp. Def'].var()
# Out:
# 773.0873775422141

# %%
pokemon['Speed'].var()
# Out:
# 861.528791352771

# %%
sns.pairplot(pokemon)
